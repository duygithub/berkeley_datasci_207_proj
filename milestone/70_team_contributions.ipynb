# %% [markdown]
# Duy contributed to Team info, motivation, EDA and visualzation.
#
# David contributed to Data description, data challenges, and provided some EDA analysis.
#
# Sabrina contributed to Data preprocessing and some EDA.
#
# Anthony contributed to Methodology and experimental design, as well as some preliminary EDA.

# %% [markdown]
# Notebook Ownership:
#
# 10_motivation - Duy
#
# 20_data_description - David
#
# 30_data_preprocessing - Sabrina
#
# 40_eda_visualization - Duy
#
# 50_data_challenges - David
#
# 60_methods_and_experiments - Anthony
#
# 70_team_contributions - Each person
