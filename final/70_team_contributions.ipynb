# %% [markdown]
# Anthony worked on related work, XGBoost, and experiments & results
# David worked on data description, baseline, neural network, and experiments and results
# Duy worked on intro, abstract, EDA, XGBoost, maintained the repo, and compiled the paper.
# Sabrina worked on data preprocessing, data distrubition accross training, validation, and conclusion.

# %% [markdown]
# <!-- Notebook Ownership:
#
# 10_motivation - Duy
#
# 20_data_description - David
#
# 30_data_preprocessing - Sabrina
#
# 40_eda_visualization - Duy
#
# 50_data_challenges - David
#
# 60_methods_and_experiments - Anthony
#
# 70_team_contributions - Each person -->
