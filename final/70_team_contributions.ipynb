# %% [markdown]
# * Anthony compiled the presentation and worked on notebooks 20, 40, 41, 50, 60, and XGBoost.
# * David discovered the dataset and worked on notebooks 30, 42, 50, and LSTM.
# * Duy compiled the paper and worked on notebooks 10, 11, 32, 50, and XGBoost.
# * Sabrina worked on notebooks 31 and 60.

# %% [markdown]
# <!-- Notebook Ownership:
#
# 10_motivation - Duy
#
# 20_data_description - David
#
# 30_data_preprocessing - Sabrina
#
# 40_eda_visualization - Duy
#
# 50_data_challenges - David
#
# 60_methods_and_experiments - Anthony
#
# 70_team_contributions - Each person -->
